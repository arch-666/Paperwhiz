# %%
# test_summarization.py

import sys
import os

# Make sure Python looks for packages in the correct location
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))  # Add root directory (where 'app' is located)

from app.models.summarizer import load_summarizer_model  # Relative import

def test_summarizer():
    summarizer_chain = load_summarizer_model()

    input_text = (
        "Artificial intelligence (AI) is a field of computer science that aims to create systems capable "
        "of performing tasks that typically require human intelligence..."
    )

    summary = summarizer_chain.invoke({"text": input_text})

    print("📄 Original text:\n", input_text)
    print("\n✂️ Summary:\n", summary)

if __name__ == "__main__":
    test_summarizer()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 3
#       1 # test_summarization.py
# ----> 3 from summarizer import load_summarizer_model
#       4 def test_summarizer():
#       5     # Load the summarization chain
#       6     summarizer_chain = load_summarizer_model()
#
# File d:\Paperwhiz\backend\app\models\summarizer.py:9
#       6 # Make sure Python looks for packages in the correct location
#       7 sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))  # Add root directory (where 'app' is located)
# ----> 9 from app.models.summarizer import load_summarizer_model  # Relative import
#      11 def test_summarizer():
#      12     summarizer_chain = load_summarizer_model()
#
# ModuleNotFoundError: No module named 'app'
